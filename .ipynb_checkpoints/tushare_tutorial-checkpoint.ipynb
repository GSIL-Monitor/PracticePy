# %%
# %load helloworld.py
from numpy import *
import tushare

print 'hello world'
print(tushare.__version__)

import tushare as ts

s = ts.get_hist_data('600000', start='2015-01-05', end='2017-04-25')
s.head()
# Out:
# hello world
# 0.6.5
#              open   high  close    low     volume  price_change  p_change  \
# date
# 2017-04-25  15.02  15.10  15.05  14.99  129759.19          0.05      0.33
# 2017-04-24  15.05  15.11  15.00  14.91  176278.03         -0.05     -0.33
# 2017-04-21  14.92  15.07  15.05  14.85  226883.58          0.14      0.94
# 2017-04-20  15.12  15.14  14.91  14.90  410614.06         -0.20     -1.32
# 2017-04-19  15.25  15.27  15.11  15.11  244554.06         -0.19     -1.24
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20
# date
# 2017-04-25  15.024  15.313  15.655  237617.78  264232.06  237992.76
# 2017-04-24  15.074  15.397  15.700  257445.91  269867.52  241455.80
# 2017-04-21  15.186  15.494  15.744  295669.19  268393.74  243754.73
# 2017-04-20  15.278  15.599  15.781  330605.58  265832.33  254316.27
# 2017-04-19  15.446  15.718  15.835  295336.07  247106.37  249347.87

# %%
s = s.sort_index()
s.head()
# Out:
#              open   high  close    low      volume  price_change  p_change  \
# date
# 2015-01-05  15.88  16.25  16.07  15.56  5135687.00          0.38      2.42
# 2015-01-06  16.00  16.68  16.13  15.82  5116845.50          0.06      0.37
# 2015-01-07  15.90  16.17  15.81  15.53  3857168.25         -0.32     -1.98
# 2015-01-08  15.87  15.88  15.25  15.20  3306271.75         -0.56     -3.54
# 2015-01-09  15.20  16.25  15.43  15.11  4919999.50          0.18      1.18
#
#                ma5    ma10    ma20       v_ma5      v_ma10      v_ma20
# date
# 2015-01-05  15.368  14.743  14.033  5036511.70  4952829.80  5451020.46
# 2015-01-06  15.640  14.947  14.163  5125914.60  5028270.15  5277038.94
# 2015-01-07  15.812  15.060  14.263  4646915.95  4730537.47  5117936.10
# 2015-01-08  15.790  15.174  14.393  4420859.20  4619585.85  4848652.79
# 2015-01-09  15.738  15.371  14.507  4467194.40  4694006.25  4784516.56

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib notebook
s['close'].plot()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
import plotly
plotly.__version__
# Out:
# '1.12.9'

# %%
import plotly.plotly as py
import plotly.graph_objs as go
py.sign_in('feixiangdream', '4lfieqCRzCqPK50EULhU')

import pandas_datareader.data as web
from datetime import datetime

trace = go.Candlestick(x=s.index,open=s['open'],high=s['high'],low=s['low'],close=s['close'])
data = [trace]
py.iplot(data, filename='simple_candlestick')
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~feixiangdream/0 or inside your plot.ly account where it is named 'simple_candlestick'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~feixiangdream/0.embed" height="525px" width="100%"></iframe>

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import numpy as np
import plotly.plotly as py

py.sign_in('feixiangdream', '4lfieqCRzCqPK50EULhU')

n = 50
x, y, z, s, ew = np.random.rand(5, n)
c, ec = np.random.rand(2, n, 4)
area_scale, width_scale = 500, 5

fig, ax = plt.subplots()
sc = ax.scatter(x, y, c=c,
                s=np.square(s)*area_scale,
                edgecolor=ec,
                linewidth=ew*width_scale)
ax.grid()

py.plot_mpl(fig)
